# %%
import pandas as pd
url='http://winterolympicsmedals.com/medals.csv'
data=pd.read_csv(url,sep=',')
data1=data[(data['Year']<2010)&(data['Year']>2001)&(data['NOC']=='GER')]
data1.groupby(['Sport','Medal']).count()
# Out:
#                   Year  City  Discipline  NOC  Event  Event gender
# Sport     Medal
# Biathlon  Bronze     3     3           3    3      3             3
#           Gold       8     8           8    8      8             8
#           Silver     9     9           9    9      9             9
# Bobsleigh Bronze     1     1           1    1      1             1
#           Gold       5     5           5    5      5             5
#           Silver     1     1           1    1      1             1
# Luge      Bronze     2     2           2    2      2             2
#           Gold       3     3           3    3      3             3
#           Silver     4     4           4    4      4             4
# Skating   Bronze     3     3           3    3      3             3
#           Gold       4     4           4    4      4             4
#           Silver     4     4           4    4      4             4
# Skiing    Bronze     5     5           5    5      5             5
# ...
